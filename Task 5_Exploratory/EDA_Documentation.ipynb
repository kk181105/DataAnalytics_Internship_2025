# %% [markdown]
# # Task 5 – Exploratory Data Analysis (EDA)
# ## Dataset: Titanic
#
# This notebook documents the EDA process and insights using visual evidence.

# %% [markdown]
# ## Objective
# To explore the dataset using statistical summaries and visualizations.

# %% [markdown]
# ## Univariate Analysis
# **Age Distribution**
#
# ![Age Distribution](visuals/age_distribution.png)
#
# **Observation:** Most passengers fall between 20–40 years of age.

# %% [markdown]
# **Gender Count**
#
# ![Gender Count](visuals/gender_count.png)
#
# **Observation:** Male passengers outnumber female passengers.

# %% [markdown]
# ## Bivariate Analysis
# **Survival by Gender**
#
# ![Survival by Gender](visuals/survival_by_gender.png)
#
# **Observation:** Female passengers had a significantly higher survival rate.

# %% [markdown]
# **Fare vs Survival**
#
# ![Fare vs Survival](visuals/fare_vs_survival.png)
#
# **Observation:** Higher fare-paying passengers were more likely to survive.

# %% [markdown]
# ## Multivariate Analysis
# **Correlation Heatmap**
#
# ![Correlation Heatmap](visuals/correlation_heatmap.png)
#
# **Observation:** Fare positively correlates with survival.

# %% [markdown]
# ## Summary of Findings
# - Females had higher survival rates
# - Higher fares improved survival chances
# - Passenger class influenced survival
